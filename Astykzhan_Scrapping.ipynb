# %% [markdown]
# # Astykzhan Shop Web Scrapping

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import re
import time

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Function opening web page:

# %%
def open_page(category, page_num, url = 'https://astykzhan.kz/catalog/list/{}/?PAGEN_1={}&city=1'):
    page_url = url.format(category, page_num)
    while True:
        try:
            page = requests.get(page_url)
            break
        except requests.exceptions.ConnectionError:
            print("TimeOut...Sleep")
            time.sleep(10)
            pass
    if page.status_code == 200:
        pages = []
        soup = BeautifulSoup(page.text, "html.parser")
        content = soup.findAll('div', class_ = 'pagenation-elem')
        for i in content:
            if len(i.text.strip('\n')) > 0:
                pages.append(int(i.text.strip('\n')))
        num_pages = max(pages)
    return page, num_pages

# %% [markdown]
# The _Grocery_ category scrapping:

# %% [markdown]
# Information about the product is inside the _product-card-elem service_product_element_ class; the detailed info is inside the _product-card-elem-name_ class, the actual price is presented in the _'product-card-elem-bottom_ class; the former price is described in the _product-card-elem-oldprice_ class.

# %%
# %%time

# sub-categories to scrap
categories_gr = ['dieticheskoe-pitanie_859',
                 'konditerskie-izdeliya-muchnye_849',
                 'konfety-shokolad-marmelad_852',
                 'kofe-kofejnye-napitki-kakao_870',
                 'kulinarnye-dobavki_876', 'muka-sahar_873',
                 'sladkaya-konservaciya_879',
                 'suhie-zavtraki-myusli-kashi_855',
                 'chaj_867','konservaciya_882',
                 'krupy-bobovye_267',
                 'makaronnye-izdeliya_270',
                 'maslo-rastitelnoe-olivkovoe_264',
                 'produkty-momentalnogo-prigotov_273',
                 'sousy_885', 'specii-i-pripravy_278',
                 'chipsy-suhariki-sneki_276']

titles_gr = []
prices_gr = []
old_prices_gr = []

for category in categories_gr:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_gr.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_gr.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_gr.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_gr.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'open_page' is not defined

# %%
len(titles_gr) == len(prices_gr)
# Out:
# True

# %%
len(titles_gr) #all parced
# Out:
# 5152

# %% [markdown]
# Household Chemicals

# %%
categories_hs = ['aerozoli-sprei_858',
                'tverdye-geli_862',
                'elektricheskie-osvezhiteli_866',
                'gubki--mochalki_188',
                'salfetki-i-tryapki-dlya-uborki_191',
                'kondicionery-opolaskivateli_821',
                'otbelivateli-pyatnovyvoditeli-_825',
                'podkrahmalivateli-sredstva-dly_829',
                'sredstva-dlya-stiralnyh-mashin_813',
                'stiralnye-sredstva_809',
                'hozyajstvennoe-mylo_817',
                'aksessuary-dlya-obuvi_206',
                'gubki-salfetki_198',
                'kremy-kraski-bleski-prochee_200',
                'prinadlezhnosti-dlya-uhoda_204',
                'specialnye-sredstva-dlya-uhoda_202',
                'prinadlezhnosti-dlya-uhoda_1',
                'sredstva-uhoda_208',
                'sredstva-ot-kleshej_3',
                'sredstva-ot-letayushih-nasekom_7',
                'sredstva-ot-moli_5',
                'sredstva-ot-polzayushih-naseko_4',
                'sredstva-dlya-mytya-posudy_833',
                'sredstva-dlya-posudomoechnyh-m_838',
                'sredstva-uhoda-za-mebelyu-kovr_848',
                'chistyashie-moyushie-sredstva_843']

# %%
# %%time
titles_hs = []
prices_hs = []
old_prices_hs = []

for category in categories_hs:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_hs.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_hs.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_hs.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_hs.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# aerozoli-sprei_858 7 1
# aerozoli-sprei_858 7 2
# aerozoli-sprei_858 7 3
# aerozoli-sprei_858 7 4
# aerozoli-sprei_858 7 5
# aerozoli-sprei_858 7 6
# aerozoli-sprei_858 7 7
# tverdye-geli_862 2 1
# tverdye-geli_862 2 2
# elektricheskie-osvezhiteli_866 4 1
# elektricheskie-osvezhiteli_866 4 2
# elektricheskie-osvezhiteli_866 4 3
# elektricheskie-osvezhiteli_866 4 4
# gubki--mochalki_188 7 1
# gubki--mochalki_188 7 2
# gubki--mochalki_188 7 3
# gubki--mochalki_188 7 4
# gubki--mochalki_188 7 5
# gubki--mochalki_188 7 6
# gubki--mochalki_188 7 7
# salfetki-i-tryapki-dlya-uborki_191 6 1
# salfetki-i-tryapki-dlya-uborki_191 6 2
# salfetki-i-tryapki-dlya-uborki_191 6 3
# salfetki-i-tryapki-dlya-uborki_191 6 4
# salfetki-i-tryapki-dlya-uborki_191 6 5
# salfetki-i-tryapki-dlya-uborki_191 6 6
# kondicionery-opolaskivateli_821 8 1
# kondicionery-opolaskivateli_821 8 2
# kondicionery-opolaskivateli_821 8 3
# kondicionery-opolaskivateli_821 8 4
# kondicionery-opolaskivateli_821 8 5
# ...

# %%
len(titles_hs)
# Out:
# 1655

# %%
len(titles_hs) == len(prices_hs)
# Out:
# True

# %% [markdown]
# Beverages

# %%
categories_bev = ['vermuty-aperitivy_788',
                  'vino_792',
                  'krepkie-spirtnye-napitki_780',
                  'mineralnaya_752',
                  'pitevaya_746',
                  'licenzionnoe_763',
                  'kvas_731',
                  'kola_716',
                  'limonady_711',
                  'prochie-napitki_741',
                  'toniki_726',
                  'holodnyj-chaj_721',
                  'energeticheskie-napitki_736',
                  'slaboalkogolnye-napitki_772',
                  'vosstanovlennye-soki-nektary_701',
                  'sokosoderzhashie-napitki-morsy_706']

# %%
# %%time
titles_bev = []
prices_bev = []
old_prices_bev = []

for category in categories_bev:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_bev.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_bev.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_bev.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_bev.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# vermuty-aperitivy_788 1 1
# vino_792 1 1
# krepkie-spirtnye-napitki_780 1 1
# mineralnaya_752 4 1
# mineralnaya_752 4 2
# mineralnaya_752 4 3
# mineralnaya_752 4 4
# pitevaya_746 8 1
# pitevaya_746 8 2
# pitevaya_746 8 3
# pitevaya_746 8 4
# pitevaya_746 8 5
# pitevaya_746 8 6
# pitevaya_746 8 7
# pitevaya_746 8 8
# licenzionnoe_763 1 1
# kvas_731 1 1
# kola_716 2 1
# kola_716 2 2
# limonady_711 10 1
# limonady_711 10 2
# limonady_711 10 3
# limonady_711 10 4
# limonady_711 10 5
# limonady_711 10 6
# limonady_711 10 7
# limonady_711 10 8
# limonady_711 10 9
# limonady_711 10 10
# prochie-napitki_741 1 1
# toniki_726 1 1
# holodnyj-chaj_721 5 1
# holodnyj-chaj_721 5 2
# holodnyj-chaj_721 5 3
# holodnyj-chaj_721 5 4
# holodnyj-chaj_721 5 5
# energeticheskie-napitki_736 5 1
# energeticheskie-napitki_736 5 2
# energeticheskie-napitki_736 5 3
# energeticheskie-napitki_736 5 4
# energeticheskie-napitki_736 5 5
# slaboalkogolnye-napitki_772 1 1
# vosstanovlennye-soki-nektary_701 22 1
# ...

# %%
len(titles_bev) #all parced
# Out:
# 952

# %% [markdown]
# Cosmetics

# %%
categories_cos = ['aksessuary-dlya-manikyura-i-pe_82',
                 'aksessuary-dlya-uhoda-za-volos_81',
                 'salfetki-platochki-polotenca_70',
                 'tualetnaya-bumaga_11',
                 'vatnye-izdeliya_92',
                 'vatnye-palochki-krome-detskih_94',
                 'vlazhnye-salfetki-krome-detski_96',
                 'zubnye-shetki-niti_72',
                 'sredstva-uhoda-za-polostyu-rta_71',
                 'dekorativnaya-kosmetika-dlya-g_576',
                 'dekorativno-kosmeticheskie-sre_585',
                 'prokladki_98',
                 'tampony_100',
                 'izdeliya-medicinskogo-naznache_86',
                 'protivozachatochnye-sredstva_88',
                 'dezodoranty_567',
                 'nabory-parfyumerno-kosmetiches_573',
                 'ochishayushie-sredstva_564',
                 'sredstva-solncezashitnye-i-dly_570',
                 'sredstva-uhoda_561',
                 'mylo-zhidkoe_636',
                 'mylo-tualetnoe_632',
                 'tualetnye-vody_600',
                 'prinadlezhnosti-dlya-prinyatiy_644',
                 'sredstva-dlya-prinyatiya-vann-_640',
                 'depilyatory_79',
                 'kartridzhi-k-britvennym-sistem_77',
                 'mnogorazovye-britvennye-sistem_76',
                 'odnorazovye-britvy_78',
                 'sredstva-dlya-britya_74',
                 'sredstva-posle-britya_75',
                 'sredstva-dlya-mytya-i-uhoda-za_552',
                 'sredstva-dlya-okraski-volos_558',
                 'sredstva-dlya-ukladki_555']

# %%
# %%time
titles_cos = []
prices_cos = []
old_prices_cos = []

for category in categories_cos:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_cos.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_cos.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_cos.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_cos.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# aksessuary-dlya-manikyura-i-pe_82 1 1
# aksessuary-dlya-uhoda-za-volos_81 1 1
# salfetki-platochki-polotenca_70 9 1
# salfetki-platochki-polotenca_70 9 2
# salfetki-platochki-polotenca_70 9 3
# salfetki-platochki-polotenca_70 9 4
# salfetki-platochki-polotenca_70 9 5
# salfetki-platochki-polotenca_70 9 6
# salfetki-platochki-polotenca_70 9 7
# salfetki-platochki-polotenca_70 9 8
# salfetki-platochki-polotenca_70 9 9
# tualetnaya-bumaga_11 7 1
# tualetnaya-bumaga_11 7 2
# tualetnaya-bumaga_11 7 3
# tualetnaya-bumaga_11 7 4
# tualetnaya-bumaga_11 7 5
# tualetnaya-bumaga_11 7 6
# tualetnaya-bumaga_11 7 7
# vatnye-izdeliya_92 4 1
# vatnye-izdeliya_92 4 2
# vatnye-izdeliya_92 4 3
# vatnye-izdeliya_92 4 4
# vatnye-palochki-krome-detskih_94 4 1
# vatnye-palochki-krome-detskih_94 4 2
# vatnye-palochki-krome-detskih_94 4 3
# vatnye-palochki-krome-detskih_94 4 4
# vlazhnye-salfetki-krome-detski_96 7 1
# vlazhnye-salfetki-krome-detski_96 7 2
# vlazhnye-salfetki-krome-detski_96 7 3
# ...

# %%
len(prices_cos) #all parced
# Out:
# 3603

# %% [markdown]
# Gastronomy

# %%
categories_gas = ['zamorozhennye-pirozhki-pirozhn_822',
                 'morozhenoe_818',
                 'myaso-i-myasoprodukty_810',
                 'polufabrikaty-iz-testa_803',
                 'ptica-i-produkty-iz-pticy_806',
                 'rybnaya-produkciya-zamorozhenn_814',
                 'frukty-yagody-ovoshi-griby_800',
                 'kolbasa-varenaya_826',
                 'kolbasa-kopchenaya_834',
                 'kopchenosti-delikatesy_839',
                 'pashtety-krome-konservirovanny_844',
                 'sosiski-sardelki_830',
                 'drugie-konditerskie-izdeliya_376',
                 'torty-pirozhnye_374',
                 'goryachaya-kulinariya_789',
                 'holodnaya-kulinariya_785',
                 'deserty-molochnye_418',
                 'jogurty-i-jogurtovye-produkty_414',
                 'kislomolochnye-napitki_405',
                 'majonez_765',
                 'margariny_754',
                 'maslo-slivochnoe-i-spredy_748',
                 'moloko_399',
                 'molochnye-produkty-dlya-detsko_422',
                 'slivki_402',
                 'smetana_408',
                 'soevye-produkty_426',
                 'syry_430',
                 'tvorog-i-tvorozhnye-izdeliya_411',
                 'yajco_760',
                 'myaso-ptica-ohlazhdennye_378',
                 'ikra_390',
                 'krabovye-palochki-myaso-rulety_384',
                 'preservy_393',
                 'ryba-solenaya-kopchenaya-vyale_387',
                 'rybnye-zakuski_396',
                 'ovoshi-griby_773',
                 'orehi-suhofrukty-ovoshi-sushen_781',
                 'frukty-yagody_769',
                 'pekarnya_2132',
                 'hleb_370',
                 'hlebobulochnye-izdeliya_372']

# %%
# %%time
titles_gas = []
prices_gas = []
old_prices_gas = []

for category in categories_gas:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_gas.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_gas.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_gas.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_gas.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# zamorozhennye-pirozhki-pirozhn_822 1 1
# morozhenoe_818 24 1
# morozhenoe_818 24 2
# morozhenoe_818 24 3
# morozhenoe_818 24 4
# morozhenoe_818 24 5
# morozhenoe_818 24 6
# morozhenoe_818 24 7
# morozhenoe_818 24 8
# morozhenoe_818 24 9
# morozhenoe_818 24 10
# morozhenoe_818 24 11
# morozhenoe_818 24 12
# morozhenoe_818 24 13
# morozhenoe_818 24 14
# morozhenoe_818 24 15
# morozhenoe_818 24 16
# morozhenoe_818 24 17
# morozhenoe_818 24 18
# morozhenoe_818 24 19
# morozhenoe_818 24 20
# morozhenoe_818 24 21
# morozhenoe_818 24 22
# morozhenoe_818 24 23
# morozhenoe_818 24 24
# myaso-i-myasoprodukty_810 3 1
# myaso-i-myasoprodukty_810 3 2
# myaso-i-myasoprodukty_810 3 3
# polufabrikaty-iz-testa_803 15 1
# polufabrikaty-iz-testa_803 15 2
# polufabrikaty-iz-testa_803 15 3
# polufabrikaty-iz-testa_803 15 4
# polufabrikaty-iz-testa_803 15 5
# polufabrikaty-iz-testa_803 15 6
# polufabrikaty-iz-testa_803 15 7
# polufabrikaty-iz-testa_803 15 8
# polufabrikaty-iz-testa_803 15 9
# ...

# %%
len(prices_gas) #all parced
# Out:
# 4075

# %% [markdown]
# Textile

# %%
categories_tex = ['golovnye-ubory_605',
                  'sumki_596',
                  'nizhnee-bele_707',
                  'trikotazhnye-izdeliya_717',
                  'chulochno-nosochnye-izdeliya_712',
                  'shvejnye-izdeliya_722',
                  'postelnoe-bele_615',
                  'postelnye-prinadlezhnosti_617',
                  'tekstil-dlya-vannoj_621',
                  'tekstil-dlya-kuhni-stolovoe-be_619',
                  'valenki_593',
                  'obuv-dlya-sada_587',
                  'obuv-dlya-sporta_590',
                  'tapochki_584',
                  'nizhnee-bele_547',
                  'trikotazhnye-izdeliya_554',
                  'chulochno-nosochnye-izdeliya_549',
                  'nizhnee-bele_742',
                  'trikotazhnye-izdeliya_759',
                  'chulochno-nosochnye-izdeliya_747']

# %%
# %%time
titles_tex = []
prices_tex = []
old_prices_tex = []

for category in categories_tex:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_tex.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_tex.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_tex.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_tex.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# golovnye-ubory_605 1 1
# sumki_596 1 1
# nizhnee-bele_707 4 1
# nizhnee-bele_707 4 2
# nizhnee-bele_707 4 3
# nizhnee-bele_707 4 4
# trikotazhnye-izdeliya_717 1 1
# chulochno-nosochnye-izdeliya_712 6 1
# chulochno-nosochnye-izdeliya_712 6 2
# chulochno-nosochnye-izdeliya_712 6 3
# chulochno-nosochnye-izdeliya_712 6 4
# chulochno-nosochnye-izdeliya_712 6 5
# chulochno-nosochnye-izdeliya_712 6 6
# shvejnye-izdeliya_722 1 1
# postelnoe-bele_615 1 1
# postelnye-prinadlezhnosti_617 1 1
# tekstil-dlya-vannoj_621 1 1
# tekstil-dlya-kuhni-stolovoe-be_619 1 1
# valenki_593 1 1
# obuv-dlya-sada_587 1 1
# obuv-dlya-sporta_590 1 1
# tapochki_584 1 1
# nizhnee-bele_547 3 1
# nizhnee-bele_547 3 2
# nizhnee-bele_547 3 3
# trikotazhnye-izdeliya_554 1 1
# chulochno-nosochnye-izdeliya_549 18 1
# chulochno-nosochnye-izdeliya_549 18 2
# chulochno-nosochnye-izdeliya_549 18 3
# chulochno-nosochnye-izdeliya_549 18 4
# chulochno-nosochnye-izdeliya_549 18 5
# chulochno-nosochnye-izdeliya_549 18 6
# ...

# %%
len(prices_tex) #all parced
# Out:
# 598

# %% [markdown]
# Other

# %%
categories_oth = ['vspomogatelnye-materialy_568',
                  'ruchnoj-instrument_559',
                  'sredstva-individualnoj-zashity_589',
                  'elektrotehnicheskie-izdeliya_556',
                  'igrushki_592',
                  'novogodnij-assortiment_595',
                  'tovary-dlya-prazdnika_598',
                  'bumazhnaya-produkciya_604',
                  'kancelyarskie-tovary_606',
                  'knigi_614',
                  'pechatnaya-produkciya_612',
                  'pressa_616',
                  'upakovochnye-materialy_610',
                  'shkolnye-kancelyarskie-tovary_608',
                  'aksessuary-dlya-bani-i-sauny_624',
                  'otdyh-na-prirode-dekor_622',
                  'rasteniya-grunty-prinadlezhnos_620',
                  'sadovoe-oborudovanie_618',
                  'zimnie-vidy-sporta_627',
                  'sportivnye-tovary-vsesezonnye_634',
                  'turizm_638',
                  'avtokosmetika-avtohimiya-tehni_661',
                  'instrument-zapchasti-rashodnye_665',
                  'prinadlezhnosti-po-uhodu-akses_669',
                  'interer-doma-osveshenie_658',
                  'kuhonnaya-posuda_646',
                  'kuhonnaya-utvar_649',
                  'predmety-dlya-domashnego-hozya_655',
                  'stolovaya-posuda_642',
                  'upakovka-i-hranenie-produktov_652']

# %%
# %%time
titles_oth = []
prices_oth = []
old_prices_oth = []

for category in categories_oth:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_oth.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_oth.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_oth.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_oth.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# vspomogatelnye-materialy_568 2 1
# vspomogatelnye-materialy_568 2 2
# ruchnoj-instrument_559 1 1
# sredstva-individualnoj-zashity_589 1 1
# elektrotehnicheskie-izdeliya_556 4 1
# elektrotehnicheskie-izdeliya_556 4 2
# elektrotehnicheskie-izdeliya_556 4 3
# elektrotehnicheskie-izdeliya_556 4 4
# igrushki_592 7 1
# igrushki_592 7 2
# igrushki_592 7 3
# igrushki_592 7 4
# igrushki_592 7 5
# igrushki_592 7 6
# igrushki_592 7 7
# novogodnij-assortiment_595 2 1
# novogodnij-assortiment_595 2 2
# tovary-dlya-prazdnika_598 2 1
# tovary-dlya-prazdnika_598 2 2
# bumazhnaya-produkciya_604 7 1
# bumazhnaya-produkciya_604 7 2
# bumazhnaya-produkciya_604 7 3
# bumazhnaya-produkciya_604 7 4
# bumazhnaya-produkciya_604 7 5
# bumazhnaya-produkciya_604 7 6
# bumazhnaya-produkciya_604 7 7
# kancelyarskie-tovary_606 11 1
# kancelyarskie-tovary_606 11 2
# kancelyarskie-tovary_606 11 3
# kancelyarskie-tovary_606 11 4
# kancelyarskie-tovary_606 11 5
# kancelyarskie-tovary_606 11 6
# ...

# %%
len(prices_oth) #all parced
# Out:
# 1969

# %% [markdown]
# Animals

# %%
categories_an = ['korm-dlya-koshek_30',
                 'korm-dlya-sobak_31',
                 'miski-tualety-sovki_3068',
                 'napolniteli-dlya-tualetov_3047']

# %%
# %%time
titles_an = []
prices_an = []
old_prices_an = []

for category in categories_an:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_an.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_an.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_an.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_an.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# korm-dlya-koshek_30 10 1
# korm-dlya-koshek_30 10 2
# korm-dlya-koshek_30 10 3
# korm-dlya-koshek_30 10 4
# korm-dlya-koshek_30 10 5
# korm-dlya-koshek_30 10 6
# korm-dlya-koshek_30 10 7
# korm-dlya-koshek_30 10 8
# korm-dlya-koshek_30 10 9
# korm-dlya-koshek_30 10 10
# korm-dlya-sobak_31 3 1
# korm-dlya-sobak_31 3 2
# korm-dlya-sobak_31 3 3
# miski-tualety-sovki_3068 1 1
# napolniteli-dlya-tualetov_3047 2 1
# napolniteli-dlya-tualetov_3047 2 2
# Wall time: 6.08 s

# %%
len(prices_an) #all parced
# Out:
# 214

# %% [markdown]
# Babies

# %%
categories_bab = ['zameniteli-moloka_766',
                 'konditerskie-izdeliya_774',
                 'pyure-smesi-konservirovannye_755',
                 'soki-napitki-voda_770',
                 'suhie-smesi_761',
                 'chulochno-nosochnye-izdeliya_83',
                 'pelenki-odnorazovye_97',
                 'podguzniki_95',
                 'aksessuary_102',
                 'bezopasnost-mladenca_103',
                 'gigiena_101',
                 'kosmetika-detskaya-i-dlya-mam_99']

# %%
# %%time
titles_bab = []
prices_bab = []
old_prices_bab = []

for category in categories_bab:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_bab.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_bab.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_bab.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_bab.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# zameniteli-moloka_766 6 1
# zameniteli-moloka_766 6 2
# zameniteli-moloka_766 6 3
# zameniteli-moloka_766 6 4
# zameniteli-moloka_766 6 5
# zameniteli-moloka_766 6 6
# konditerskie-izdeliya_774 4 1
# konditerskie-izdeliya_774 4 2
# konditerskie-izdeliya_774 4 3
# konditerskie-izdeliya_774 4 4
# pyure-smesi-konservirovannye_755 18 1
# pyure-smesi-konservirovannye_755 18 2
# pyure-smesi-konservirovannye_755 18 3
# pyure-smesi-konservirovannye_755 18 4
# pyure-smesi-konservirovannye_755 18 5
# pyure-smesi-konservirovannye_755 18 6
# pyure-smesi-konservirovannye_755 18 7
# pyure-smesi-konservirovannye_755 18 8
# pyure-smesi-konservirovannye_755 18 9
# pyure-smesi-konservirovannye_755 18 10
# pyure-smesi-konservirovannye_755 18 11
# pyure-smesi-konservirovannye_755 18 12
# pyure-smesi-konservirovannye_755 18 13
# pyure-smesi-konservirovannye_755 18 14
# pyure-smesi-konservirovannye_755 18 15
# pyure-smesi-konservirovannye_755 18 16
# pyure-smesi-konservirovannye_755 18 17
# ...

# %%
len(prices_bab) #all parced
# Out:
# 1016

# %% [markdown]
# Appliances

# %%
categories_app = ['elementy-pitaniya-i-zaryadnye-_724',
                  'aksessuary-dlya-melkobytovoj-t_647',
                  'tehnika-dlya-komforta_635',
                  'tehnika-dlya-krasoty-i-zdorovy_639',
                  'tehnika-dlya-kuhni_631',
                  'elektropribory-po-uhodu-za-bel_643',
                  'otoplenie_705']

# %%
# %%time
titles_app = []
prices_app = []
old_prices_app = []

for category in categories_app:
    page, num_pages = open_page(category, 1)
    for i in np.arange(1,num_pages + 1):
        print(category, num_pages, i)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            content = soup.findAll('div', class_ = 'product-card-elem service_product_element')
            for product in content:
                titles_app.append(product.find('div', {'class': 'product-card-elem-name'}).text.replace('\n',''))
                price = product.find('div', {'class': 'product-card-elem-bottom'}).find('span').text
                prices_app.append(price)
                string = product.find('div', {'class': 'product-card-elem-oldprice'}).find('span')
                if string is None:
                    old_prices_app.append(price)
                else:
                    string = str(string)
                    old_price = re.search('\d+', string)
                    old_prices_app.append(old_price[0])
        else:
            print(page.status_code)
# Out:
# elementy-pitaniya-i-zaryadnye-_724 2 1
# elementy-pitaniya-i-zaryadnye-_724 2 2
# aksessuary-dlya-melkobytovoj-t_647 1 1
# tehnika-dlya-komforta_635 1 1
# tehnika-dlya-krasoty-i-zdorovy_639 1 1
# tehnika-dlya-kuhni_631 1 1
# elektropribory-po-uhodu-za-bel_643 1 1
# otoplenie_705 1 1
# Wall time: 7.07 s

# %%
len(prices_app) #all parced
# Out:
# 73

# %% [markdown]
# All the scrapped data are put inside the dataframes, that are combined together.

# %%
data_gr = pd.DataFrame({'product':titles_gr, 'price':prices_gr, 'old_price':old_prices_gr})
data_gr['category'] = 'Grocery'

# %%
data_hs = pd.DataFrame({'product':titles_hs, 'price':prices_hs, 'old_price':old_prices_hs})
data_hs['category'] = 'Chemicals'

# %%
data_bev = pd.DataFrame({'product':titles_bev, 'price':prices_bev, 'old_price':old_prices_bev})
data_bev['category'] = 'Beverages'

# %%
data_cos = pd.DataFrame({'product':titles_cos, 'price':prices_cos, 'old_price':old_prices_cos})
data_cos['category'] = 'Cosmetics'

# %%
data_gas = pd.DataFrame({'product':titles_gas, 'price':prices_gas, 'old_price':old_prices_gas})
data_gas['category'] = 'Gastronomy'

# %%
data_tex = pd.DataFrame({'product':titles_tex, 'price':prices_tex, 'old_price':old_prices_tex})
data_tex['category'] = 'Textile'

# %%
data_oth = pd.DataFrame({'product':titles_oth, 'price':prices_oth, 'old_price':old_prices_oth})
data_oth['category'] = 'Household'

# %%
data_an = pd.DataFrame({'product':titles_an, 'price':prices_an, 'old_price':old_prices_an})
data_an['category'] = 'For Animals'

# %%
data_bab = pd.DataFrame({'product':titles_bab, 'price':prices_bab, 'old_price':old_prices_bab})
data_bab['category'] = 'For Babies'

# %%
data_app = pd.DataFrame({'product':titles_app, 'price':prices_app, 'old_price':old_prices_app})
data_app['category'] = 'Appliances'

# %%
data = pd.concat([data_gr, data_hs, data_bev, data_cos, data_gas, data_tex, data_oth, data_an, data_bab, data_app],
                 ignore_index = True)
data.shape
# Out:
# (19307, 4)

# %% [markdown]
# Export to Excel

# %%
data.to_excel('astykzhan.kz.xlsx')
